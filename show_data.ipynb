# %%
#import ROOT
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
pathes = os.listdir('.')
pathes = [i for i in pathes if i[:3]=='OF5' and i[-4:]!='root']

pathes
# Out:
# ['OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BT1_constGapLowE_bunchLength5_size22',
#  'OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BT1_rdGapHighE_bunchLength5_size22',
#  'OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BT1_onlyPileup_bunchLength5_size22',
#  'OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BT1_constGapHighE_bunchLength5_size22',
#  'OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BT1_rdGapLowE_bunchLength5_size22',
#  'OF5_EMB_EMMiddle_eta0.5125_phi0.0125_mu140_BTF72E8_rdGapHighE_bunchLength5_size2']

# %%
os.listdir(pathes[0]+'/')
# Out:
# ['.DS_Store', '1_of', '0_digitization']

# %%
_, path1, path0 = os.listdir(pathes[0]+'/')

arr1, arr0 = os.listdir(pathes[0]+'/'+path1), os.listdir(pathes[0]+'/'+path0)

arr1, arr0
# Out:
# (['configuration.txt', 'digits_out_sequence_eT.txt'],
#  ['hit_eT_sig_sequence.txt',
#   'digits_out_sequence_eT.txt',
#   'ideal_output_sequence.txt',
#   'hit_eT_bck_sequence.txt'])

# %%
# pulse shape

for i in range(len(pathes)):
    arr = np.loadtxt(pathes[i]+'/'+path0+'/'+arr0[1])
    plt.figure(figsize=(5,3))
    plt.plot(arr[100000:100200])
    plt.xlabel('Brunch Crossing')
    plt.ylabel('Amplitude')
    plt.show()

# %%
for i in range(len(pathes)):
    arr = np.loadtxt(pathes[i]+'/'+path0+'/'+arr0[1])
    print(len(arr))
# Out:
# 22000000
# 22000000
# 22000000
# 22000000
# 22000000
# 2000000

# %%
for i in range(len(pathes)):
    arr = np.loadtxt(pathes[i]+'/'+path0+'/'+arr0[0])
    plt.plot(arr[100000:100200])
    plt.show()

# %%
for i in range(len(pathes)):
    arr = np.loadtxt(pathes[i]+'/'+path0+'/'+arr0[3])
    plt.plot(arr[100000:100200])
    plt.show()

# %%
for i in range(len(pathes)):
    arr = np.loadtxt(pathes[i]+'/'+path0+'/'+arr0[1])
    plt.plot(arr[0:10000])
    plt.show()
